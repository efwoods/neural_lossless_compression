# %% [markdown]
# # Data Exploration and Visualization
#
# Visualizing samples of the data to better understand the dataset

# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile
import os

# %%
data_folder = "./data/"

# %%
# grab name of one file in the folder
data_dir = os.listdir("./data/")
example_filepath = os.path.join(data_folder, data_dir[0])

# %%
sample_rate, data = wavfile.read(example_filepath)
sample_rate, data.shape
# 98699 / 19531 = 5.0534534842045975 seconds of recordings
# Out:
# (19531, (98699,))

# %%
plt.figure(figsize=(10, 4))
plt.plot(data)
plt.title('Waveform of the Audio File')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(data[:400])
plt.title('Waveform of the Audio File, first 400 samples')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(data[:100])
plt.title('Waveform of the Audio File, first 400 samples')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.show()

# %%
type(data[0]), max(data), min(data)
# Out:
# (numpy.int16, 6437, -4132)

# %% [markdown]
# Note, the data is given to be 10-bit/sample, hence the int16 representation used in the scipy

# %% [markdown]
# Credits:
#
# Reuben Thomas, reubenkthomas@berkeley.edu;
